# %% [markdown]
# <a href="https://colab.research.google.com/github/iiLolaii/data-management-262/blob/main/g_drive_script_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Data Management - Final/dm_script_test.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                         doi  \
# 0             0           0  https://doi.org/10.1186/s40862-020-00088-w
# 1             1           1  https://doi.org/10.1186/s40862-020-00081-3
# 2             2           2  https://doi.org/10.1186/s40862-021-00118-1
# 3             3           3  https://doi.org/10.1186/s40862-021-00117-2
# 4             4           4  https://doi.org/10.1186/s40862-021-00116-3
#
#                                                title  \
# 0  A comparative study of the effect of teacher’s...
# 1  Examining the influence of native and non-nati...
# 2  Profiling the pausing behaviour of EFL learner...
# 3  Epistemological beliefs and conceptions about ...
# 4  Maltese as a foreign language educators’ acqui...
#
#                                        authors  \
# 0  Zahra Pourmousavi, Zohre Mohamadi Zenouzagh
# 1                               Andrew Schenck
# 2                 Shen Cuiping, Chen Ningyang
# ...

# %%
df["primary_sources"] = df["primary_sources"].str.lower()
df["secondary_sources"] = df["secondary_sources"].str.lower()


df["authors"] = df["authors"].str.replace(",", ";")
df["publication_year"] = df["publication_year"].astype('Int64')


df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                         doi  \
# 0             0           0  https://doi.org/10.1186/s40862-020-00088-w
# 1             1           1  https://doi.org/10.1186/s40862-020-00081-3
# 2             2           2  https://doi.org/10.1186/s40862-021-00118-1
# 3             3           3  https://doi.org/10.1186/s40862-021-00117-2
# 4             4           4  https://doi.org/10.1186/s40862-021-00116-3
#
#                                                title  \
# 0  A comparative study of the effect of teacher’s...
# 1  Examining the influence of native and non-nati...
# 2  Profiling the pausing behaviour of EFL learner...
# 3  Epistemological beliefs and conceptions about ...
# 4  Maltese as a foreign language educators’ acqui...
#
#                                        authors  \
# 0  Zahra Pourmousavi; Zohre Mohamadi Zenouzagh
# 1                               Andrew Schenck
# 2                 Shen Cuiping; Chen Ningyang
# ...
